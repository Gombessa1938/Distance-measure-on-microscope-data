# %%
from math import sqrt 
import numpy as np

def findCircle(x1, y1, x2, y2, x3, y3) : 
    x12 = x1 - x2;  
    x13 = x1 - x3;  
  
    y12 = y1 - y2;  
    y13 = y1 - y3;  
  
    y31 = y3 - y1;  
    y21 = y2 - y1;  
  
    x31 = x3 - x1;  
    x21 = x2 - x1;  
  
    # x1^2 - x3^2  
    sx13 = pow(x1, 2) - pow(x3, 2);  
  
    # y1^2 - y3^2  
    sy13 = pow(y1, 2) - pow(y3, 2);  
  
    sx21 = pow(x2, 2) - pow(x1, 2);  
    sy21 = pow(y2, 2) - pow(y1, 2);  
  
    f = (((sx13) * (x12) + (sy13) * 
          (x12) + (sx21) * (x13) + 
          (sy21) * (x13)) // (2 * 
          ((y31) * (x12) - (y21) * (x13)))); 
              
    g = (((sx13) * (y12) + (sy13) * (y12) + 
          (sx21) * (y13) + (sy21) * (y13)) // 
          (2 * ((x31) * (y12) - (x21) * (y13))));  
  
    c = (-pow(x1, 2) - pow(y1, 2) - 
         2 * g * x1 - 2 * f * y1);  
  
    # eqn of circle be x^2 + y^2 + 2*g*x + 2*f*y + c = 0  
    # where centre is (h = -g, k = -f) and  
    # radius r as r^2 = h^2 + k^2 - c  
    h = -g;  
    k = -f;  
    sqr_of_r = h * h + k * k - c;  
  
    # r is the radius  
    r = round(sqrt(sqr_of_r), 5);  
  
    #print("Centre = (", h, ", ", k, ")");  
    #print("Radius = ", r);  
    center = np.array([[h],[k]])
    #print(center)
    return center,r

# %%
import numpy as np
import cv2
import math
from numpy import linalg as LA
import csv

#37x is 6.62938
#70x is 3.166775
#100x is 2.23227833
#units = 1#float(input('please enter sample size in micron per pixel:'))


units = int(input('please enter zoom as 37, 70, or 100'))

if units == 37:
    s = 6.62938
if units == 70:
    s = 3.166775
if units == 100:
    s = 2.23227833

first = np.zeros((2,1))
second = np.zeros((2,1))


x_position = []
y_position = []
counter = 0
B_counter = 0
x2_position =[]
y2_position =[]
result_to_csv = []
k = 0
def click_event(event,x,y,flags,param):
    global first,second,img,center1,center2,r,counter,B_counter
    #global cache
    if event == cv2.EVENT_LBUTTONDOWN:
        counter +=1 
        #cache = img.copy()
        x_position.append(x)
        y_position.append(y)
        #print('(',x,' , ',y,')')
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = 'point '
        
        cv2.circle(img, (x,y),0,(225,0,0),3)
        cv2.imshow('image',img)
        first[0] = float(x)
        first[1] = float(y)
        
        if counter >= 2 and counter %3 == 0:
            
            center1,r = findCircle(x1 = float(x_position[counter -3]),y1 = float(y_position[counter-3]),x2=float(x_position[counter -2]),
                                   y2=float(y_position[counter-2]),x3=float(x_position[counter-1]),y3=float(y_position[counter-1]))
            cv2.circle(img, ((int(center1[0]),int(center1[1]))), 0, (0,0,225), 3)
            cv2.imshow('image',img)
            cv2.circle(img, ((int(center1[0]),int(center1[1]))), int(np.round(r)), (0,0,225), 2)
            cv2.imshow('image',img)
            cv2.line(img, (int(center1[0]), int(center1[1]-int(np.round(0.5*r)))),
                     (int(center1[0]), int(center1[1]+int(np.round(0.5*r)))), (0, 0, 225),
                     thickness=2)
            cv2.imshow('image',img)
            cv2.line(img, (int(center1[0]-int(np.round(0.5*r))), int(center1[1])),
                     (int(center1[0]+int(np.round(0.5*r))), int(center1[1])), (0, 0, 225),
                     thickness=2)
            cv2.imshow('image',img)            
            
            
            
            
            #mark cross on center
            
            
            
    if event ==cv2.EVENT_RBUTTONDOWN:
        B_counter +=1
        x2_position.append(x)
        y2_position.append(y)
        
        
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = 'point'#str(x) + ',' + str(y)
        #cv2.putText(img, strXY,(x,y),font,1,(0,0,225),3)
        cv2.circle(img, (x,y),0,(0,0,225),3)
        cv2.imshow('image',img)
        second[0] = float(x)
        second[1] = float(y)
        #print(second)
        if B_counter >= 2 and B_counter %3 ==0:
            center2,r = findCircle(x1 = float(x2_position[B_counter-3]),y1 = float(y2_position[B_counter-3]),
                                   x2=float(x2_position[B_counter-2]),y2=float(y2_position[B_counter-2]),
                     x3=float(x2_position[B_counter - 1]),y3=float(y2_position[B_counter-1]))
            #print(center2)
            cv2.circle(img, (int(center2[0]),int(center2[1])), 0, (0,0,225), 3)
            cv2.imshow('image',img)
            cv2.circle(img, ((int(center2[0]),int(center2[1]))), int(np.round(r)), (0,0,225), 2)
            cv2.imshow('image',img)
            
            
            
            #mark on center
            cv2.line(img, (int(center2[0]), int(center2[1]-int(np.round(0.5*r)))),
                     (int(center2[0]), int(center2[1]+int(np.round(0.5*r)))), (0, 0, 225),
                     thickness=2)
            cv2.imshow('image',img)
            cv2.line(img, (int(center2[0]-int(np.round(0.5*r))), int(center2[1])),
                     (int(center2[0]+int(np.round(0.5*r))), int(center2[1])), (0, 0, 225),
                     thickness=2)
            cv2.imshow('image',img)            
            
        
            dist = LA.norm(center1 - center2)*s
        
            print(round(dist,5),'micron')
            result_to_csv.append(dist)
            strDist = 'distance is:' + str(round(dist,3)) +'um'
        
            cv2.putText(img, strDist,(int(center2[0])+50,int(center2[1])+50),font,1,(225,100,225),3)
            cv2.imshow('image',img)
            
            cv2.line(img, (int(center1[0]),int(center1[1])), (int(center2[0]),int(center2[1])), (0,0,225), thickness=2)
            cv2.imshow('image',img)
    #if event == cv2.EVENT_MBUTTONDOWN:
        #img = cache
        #cv2.imshow('image',img)
        
k+=1

print('for exampe, C:\\Users\\Joe\\python code\\cv2\\cal1.JPG ')
print('')
print('')











path = str(input())
img = cv2.imread(path)
#cache = img.copy()
cv2.imshow('image',img)
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# please enter zoom as 37, 70, or 100 37
# for exampe, C:\Users\Joe\python code\cv2\cal1.JPG
#  C:\Users\Joe\python code\cv2\cal1.JPG
# 5052.02254 micron
# 6803.1071 micron

# %%
with open('data' + str(k)+'.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(result_to_csv)
